# %%
import operator
import numpy as np
import numpy_financial as npf
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.float_format', lambda x: '%.2f' % x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Scenario
# Many in industry have taken the leap from on premise to cloud based infrastructure. In the following scenario, we will examine this real world problem using Monte Carlo simulation for standard line items of an on premise to cloud migration. For you inidividual case, you may have other cost to consider as well. For the cloud provider, we are using Google and Databricks for analytics platform. Here I have rolled up their cost into one line item but you may want to break them out for a more robust analysis.
#
# In the case laid out below, we have that
# 1. `data_center_thb` is the cost data center per year in Thai Baht.
# 2. `servers` are the number of servers we maintain.
# 3. `software` is the cost of enterprise licenses we pay for.
# 4. `engineers_thb` is the cost of all our engineers who would have responsibilities covered by migrating cloud.
# 5. `pro_service` is the professional service fee from GCP and Databricks for transitioning from on premise to cloud.
# 6. `hurdle_rate` is the business risk of capital rate; however, we can use a distribution for this value to look different rates.
#
# This notebook can be modified for traditional applications such as manufactoring or other tech style evaluations. This isn't solely for analyzing on premise to cloud but just the example used here today.

# %%
data_center_thb = 26400000
cycle_one_hardware = 990000
servers = 150
software = 300000
engineers_thb = 2227500 * 20   # 20 engineers at ~2.2M THB a year
pro_service = -1000000
tax_rate = .2                  # corporate tax rate incurred on all positive revenues
hurdle_rate = .1               # risk adjusted hurdle rate can compute by using the function below instead of this static value
year_one_thb = 33
# working with your vendors, you should be profile your current usage
initial_dbu_from_profiler = -650000
initial_vm_from_profiler= -450000
initial_storage = -875000
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Standard Distributions
# Common distributions to use during capital budgeting Monte Carlo are `triangular`, `uniform`, and `normal`. However, others may be used with care. If one uses a normal distribution, remember the tails trail off to negative and positive infinity which may or may not make sense for your scenario. Even though the probability may be small of selection beyond 3 standard deviations, it can happen in large number of simulations. With normal distributions, it might be good to define lower and upper bounds to assign to anything selected beyond a certain range. Another option is to use distributions that have support and only needing to bound at one extreme.
#
# In the distributions below, I demonstrate the use of `uniform`, `triangular`, and `normal`, but dont feel limited to these. If you know one of your cost has a `beta` distribution, use it. If you are a US user with US cost, you will not need the exchange rate throughout the this demo. You can either remove it or set it to 1 since dividing by will not change the end result.

# %%
def hardware_thb():
    """
    Cost of the hardware per server in THB.
    """
    return np.random.uniform(850000, 1000000)
  
  
def data_growth():
  """
  Data growth of the cluster.
  """
  return np.random.triangular(1.03, 1.04, 1.05)


def software_increase():
    """
    Percentage increase of software licenses yearly.
    """
    return np.random.triangular(1.005, 1.025, 1.05)


def engineers_increase():
    """
    Percentage increase of the salary of the engineers per year.
    """
    return np.random.triangular(1.05, 1.085, 1.12)


def engineers_resource_utilization():
    """
    The percentage of billable time the engineers would spend on cloud related task that would be
    freed up if we move to cloud.
    """
    return np.random.triangular(0.35, 0.45, 0.5)


def data_center_cost_increase():
    """
    Data center shared space cost increase yearly.
    """
    return np.random.triangular(1.005, 1.01, 1.035)


def exchange_thb():
    """
    THB to USD exchange rate flucuation with a mean of 32 and SD of 2. In this case, we will bound the return
    values to a minimum of 28 and a maximum of 38.
    """
    thb = np.random.normal(32, 2)
    if thb < 28:
      return 30
    if thb > 36:
      return 36
    return thb


def year_one_dual_cost():
    """
    During the first year transition phase, we will experience partial on premise and cloud cost depending
    on the speed of migration.
    """
    return np.random.triangular(.25, .35, .5)
  
  
def risk_adjusted_hurdle():
  """
  We cannot account for every risk profile in this simulation; therefore, we can capture some of this additional
  risk by considering hurdle rate which incorporates a higher return needed.
  """
  return np.random.triangular(.10, .125, .20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def create_data():
    # if you have more line items to account for, update the indices needed here.
    # setup dataframe
    df = pd.DataFrame([], columns=[f"year_{i}" for i in range(0, 11)])
    df.loc[:, "index"] = ["data_center", "hardware", "engineers", "software", "dbus", "gcp_vms", "gcp_storage", "cashflows", "after_tax"]
    df.set_index("index", inplace=True)
    df.fillna(0, inplace=True)
    # initialize year_0
    df.loc["cashflows", "year_0"] = pro_service
    df.loc["after_tax", "year_0"] = pro_service
    
    # cloud/prem
    premise = ["data_center", "hardware", "engineers", "software"]
    cloud = ["dbus", "gcp_vms", "gcp_storage"]

    for i in range(1, 11):
        # not the cleanest but just doing first year value setting and checking for cycle update params
        if i == 1:
            dual_cost = year_one_dual_cost()                              
            hardware = cycle_one_hardware / year_one_thb / 5 * servers 
            engineer_pay = engineers_thb / year_one_thb / 3
            # utilization_split = engineers_resource_utilization()
            utilization_split = 0.5  # using 0.5 here to mimic the example online
        elif i == 2:
            data_increase = data_growth()
            engineer_pay = engineers_thb * engineers_increase() / exchange_thb() * engineers_resource_utilization()
        elif i == 6:
            rate = exchange_thb()
            engineer_pay = engineers_thb * engineers_increase() / rate * engineers_resource_utilization()
            hardware = hardware_thb() / rate / 5 * servers    # hardware upgrade cycle split cost over 5 years
            data_increase = data_growth()
        else:
            engineer_pay = engineers_thb * engineers_increase() / exchange_thb() * engineers_resource_utilization()
            data_increase = data_growth()
  
        # populate the data
        df.loc["data_center", f"year_{i}"] = data_center_thb / year_one_thb if i == 1 else df.loc["data_center", f"year_{i - 1}"] * data_center_cost_increase()
        df.loc["hardware", f"year_{i}"] = hardware
        df.loc["engineers", f"year_{i}"] = engineer_pay 
        df.loc["software", f"year_{i}"] = software if i == 1 else df.loc["software", f"year_{i - 1}"] * software_increase()
        # here I am just assuming data increase will reflect linear on dbus and vms
        # this probably not the case so you can this more preceise or take this estimate
        df.loc["dbus", f"year_{i}"] = initial_dbu_from_profiler if i == 1 else df.loc["dbus", f"year_{i - 1}"] * data_increase
        df.loc["gcp_vms", f"year_{i}"] = initial_vm_from_profiler if i == 1 else df.loc["gcp_vms", f"year_{i - 1}"] * data_increase
        df.loc["gcp_storage", f"year_{i}"] = initial_storage_from_profiler if i == 1 else df.loc["gcp_storage", f"year_{i - 1}"] * data_increase
        df.loc["cashflows", f"year_{i}"] = df.loc[premise, f"year_{i}"].sum() * utilization_split + df.loc[cloud, f"year_{i}"].sum() * (1 - utilization_split) if i == 1 else df.loc[premise, f"year_{i}"].sum() + df.loc[cloud, f"year_{i}"].sum()
        df.loc["after_tax", f"year_{i}"] = df.loc["cashflows", f"year_{i}"] if df.loc["cashflows", f"year_{i}"] <= 0 else df.loc["cashflows", f"year_{i}"] * 0.8
        
    return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# take a look at the dataframe and see how each call changes the results
create_data()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[63]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year_0</th>
#       <th>year_1</th>
#       <th>year_2</th>
#       <th>year_3</th>
#       <th>year_4</th>
#       <th>year_5</th>
#       <th>year_6</th>
#       <th>year_7</th>
#       <th>year_8</th>
#       <th>year_9</th>
#       <th>year_10</th>
#     </tr>
#     <tr>
#       <th>index</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>data_center</th>
#       <td>0</td>
#       <td>800000.00</td>
#       <td>808952.94</td>
#       <td>828013.72</td>
#       <td>835835.88</td>
#       <td>844058.42</td>
#       <td>851327.80</td>
#       <td>870442.81</td>
#       <td>880336.60</td>
#       <td>894034.86</td>
#       <td>904151.33</td>
#     </tr>
#     <tr>
#       <th>hardware</th>
#       <td>0</td>
#       <td>900000.00</td>
#       <td>900000.00</td>
#       <td>900000.00</td>
#       <td>900000.00</td>
#       <td>900000.00</td>
#       <td>877371.05</td>
#       <td>877371.05</td>
#       <td>877371.05</td>
#       <td>877371.05</td>
#       <td>877371.05</td>
#     </tr>
#     <tr>
#       <th>engineers</th>
#       <td>0</td>
#       <td>450000.00</td>
#       <td>628370.54</td>
#       <td>549193.51</td>
#       <td>779881.89</td>
#       <td>742931.32</td>
#       <td>711201.27</td>
#       <td>683846.53</td>
#       <td>715213.75</td>
#       <td>707461.16</td>
#       <td>620593.65</td>
#     </tr>
#     <tr>
#       <th>software</th>
#       <td>0</td>
#       <td>300000.00</td>
#       <td>312852.30</td>
#       <td>322682.70</td>
#       <td>329119.97</td>
#       <td>339284.10</td>
#       <td>353372.34</td>
#       <td>359653.11</td>
#       <td>368833.60</td>
#       <td>374509.71</td>
#       <td>389573.67</td>
#     </tr>
#     <tr>
#       <th>dbus</th>
#       <td>0</td>
#       <td>-650000.00</td>
#       <td>-674652.35</td>
#       <td>-698686.92</td>
#       <td>-730930.62</td>
#       <td>-761151.34</td>
#       <td>-788535.46</td>
#       <td>-820049.67</td>
#       <td>-854091.91</td>
#       <td>-891850.07</td>
#       <td>-928622.14</td>
#     </tr>
#     <tr>
#       <th>gcp_vms</th>
#       <td>0</td>
#       <td>-450000.00</td>
#       <td>-467067.01</td>
#       <td>-483706.33</td>
#       <td>-506028.89</td>
#       <td>-526950.92</td>
#       <td>-545909.16</td>
#       <td>-567726.69</td>
#       <td>-591294.40</td>
#       <td>-617434.67</td>
#       <td>-642892.25</td>
#     </tr>
#     <tr>
#       <th>gcp_storage</th>
#       <td>0</td>
#       <td>-875000.00</td>
#       <td>-908185.86</td>
#       <td>-940540.08</td>
#       <td>-983945.06</td>
#       <td>-1024626.80</td>
#       <td>-1061490.04</td>
#       <td>-1103913.02</td>
#       <td>-1149739.11</td>
#       <td>-1200567.40</td>
#       <td>-1250068.26</td>
#     </tr>
#     <tr>
#       <th>cashflows</th>
#       <td>-1000000</td>
#       <td>237500.00</td>
#       <td>600270.56</td>
#       <td>476956.60</td>
#       <td>623933.17</td>
#       <td>513544.79</td>
#       <td>397337.80</td>
#       <td>299624.12</td>
#       <td>246629.59</td>
#       <td>143524.65</td>
#       <td>-29892.95</td>
#     </tr>
#     <tr>
#       <th>after_tax</th>
#       <td>-1000000</td>
#       <td>190000.00</td>
#       <td>480216.45</td>
#       <td>381565.28</td>
#       <td>499146.54</td>
#       <td>410835.83</td>
#       <td>317870.24</td>
#       <td>239699.30</td>
#       <td>197303.67</td>
#       <td>114819.72</td>
#       <td>-29892.95</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # 25000 Simulation
# This is a bit slow at 25k but not bad at 10k. we can always use the multiple processing package to speed up the run time.

# %%
# collect data for before and after tax npv and irr for years 3, 5, 10
# you can run NPV, IRR for both before and after tax
# in this case, I will just be using after tax but feel free to use whatever method you want to use

# npv_irr_10 = []
npv_irr_after_tax_10 = []
# npv_irr_5 = []
npv_irr_after_tax_5 = []
# npv_irr_3 = []
npv_irr_after_tax_3 = []
for _iter in range(1, 25001):
    df = create_data()
    # for a static hurdle rate, risk = hurdle_rate
    risk = risk_adjusted_hurdle()
#     npv_irr_10.append(
#         (
#             round(npf.npv(risk, df.loc["cashflows", :].values[1:11]) + df.loc["cashflows", "year_0"], 2),
#             round(npf.irr(df.loc["cashflows", :].values[0:11]), 2) * 100
#         )
#     )
    npv_irr_after_tax_10.append(
        (
            round(npf.npv(risk, df.loc["after_tax", :].values[1:11]) + df.loc["after_tax", "year_0"], 2),
            round(npf.irr(df.loc["after_tax", :].values[0:11]), 2) * 100
        )
    )
#     npv_irr_5.append(
#         (
#             round(npf.npv(risk, df.loc["cashflows", :].values[1:6]) + df.loc["cashflows", "year_0"], 2),
#             round(npf.irr(df.loc["cashflows", :].values[0:6]), 2) * 100
#         )
#     )
    npv_irr_after_tax_5.append(
        (
            round(npf.npv(risk, df.loc["after_tax", :].values[1:6]) + df.loc["after_tax", "year_0"], 2),
            round(npf.irr(df.loc["after_tax", :].values[0:6]), 2) * 100
        )
    )
#     npv_irr_3.append(
#         (
#             round(npf.npv(risk, df.loc["cashflows", :].values[1:4]) + df.loc["cashflows", "year_0"], 2),
#             round(npf.irr(df.loc["cashflows", :].values[0:4]), 2) * 100
#         )
#     )
    npv_irr_after_tax_3.append(
        (
            round(npf.npv(risk, df.loc["after_tax", :].values[1:4]) + df.loc["after_tax", "year_0"], 2),
            round(npf.irr(df.loc["after_tax", :].values[0:4]), 2) * 100
        )
    )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_results_plot(npv_irr_array, num_years, before_tax=True):
    """
    Plot the distributions of NPV for the given years and factor in tax or not.
    :param npv_irr_array: array containing a tuple of npv, irr
    :param num_years: in our case, I only look at 3, 5, 10
    :para before_tax: if you want after tax calculations, you would specify that here.
    """
    npv = list(map(operator.itemgetter(0), npv_irr_array))
    irr = list(map(operator.itemgetter(1), npv_irr_array))

    if before_tax:
      naming = "before"
    else:
      naming = "after"

    plt.figure(figsize=(15, 10))
    plt.xlabel("NPV in USD")
    plt.ylabel("Frequency")
    plt.title(f"{num_years} Year {naming} Tax NPV")
    N, bins, patches = plt.hist(npv, bins=85, density=True, stacked=True)
    
    # pick 2 colors for NPV < 0 and > 0; red and green/black looked bad in my opinion
    for i in range(0, len(bins) - 1):
      if patches[i].xy[0] < 0:
        patches[i].set_facecolor("black")
      else:
        patches[i].set_facecolor("blue")
    
    plt.show()
    return npv, irr
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Before Tax NPV

# %%
# npv_3, irr_3 = get_results_plot(npv_irr_3, "3")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# npv_5, irr_5 = get_results_plot(npv_irr_5, "5")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# npv_10, irr_10 = get_results_plot(npv_irr_10, "10")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # After Tax NPV

# %%
npv_3_after, irr_3_after = get_results_plot(npv_irr_after_tax_3, "3", before_tax=False)

# %%
npv_5_after, irr_5_after = get_results_plot(npv_irr_after_tax_5, "5", before_tax=False)

# %%
npv_10_after, irr_10_after = get_results_plot(npv_irr_after_tax_10, "10", before_tax=False)

# %%
print("10 year")
print(len([i for i in npv_10_after if i >= 0]) / 25000)
print(np.mean(npv_10_after))
print(np.median(npv_10_after))
print(min(npv_10_after))
print(max(npv_10_after))
print("\n5 Year")
print(len([i for i in npv_5_after if i >= 0]) / 25000)
print(np.mean(npv_5_after))
print(np.median(npv_5_after))
print(min(npv_5_after))
print(max(npv_5_after))
print("\n3 Year")
print(len([i for i in npv_3_after if i >= 0]) / 25000)
print(np.mean(npv_3_after))
print(np.median(npv_3_after))
print(min(npv_3_after))
print(max(npv_3_after))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10 year
# 1.0
# 771416.2021456
# 765448.8500000001
# 95968.44
# 1584911.55
#
# 5 Year
# 1.0
# 446193.3036508
# 445546.48
# 87188.61
# 822078.65
#
# 3 Year
# 0.33152
# -27663.3997212
# -27810.395
# -252839.84
# 229587.55
# </div>

# %% [markdown]
# # Interpreting Results
# We will only look at the after tax results in this scenario of `25k` simulations.
#
# During our analysis, we have pulled out data for `3`, `5`, and `10` years. Given the following capital flows and distributions (determine with your company and cloud providers about what is reasonable), we have the following results for undertaking a project of migrating from on premise to cloud. For the `3` year period, we have that
# * `33.15%` of the results would yield a non-zero NPV,
# * a mean NPV of `-27,663` USD,
# * a median NPV of `-27,810` USD,
# * a minimum NPV of `-252,839` USD, and
# * a maximum NPV of `229,587` USD
#
# If we had such a short time horizon, the risk of migrating to cloud wouldn't make sense in my opinion with only a `33%` chance of a profitable outcome. Next, let's consider the `5` year results.
# * `100%` of the results would yield a non-zero NPV,
# * a mean NPV of `446,193` USD,
# * a median NPV of `445,546` USD,
# * a minimum NPV of `87,188` USD, and
# * a maximum NPV of `822,078` USD
#
# In the case of a `5` year time horizon, migrating to cloud would seem like a smart move in my opinion. There are some risk since in `32%` of the simulations, the factors combined to produce a negative outcome. Finally, let's look at the `10` year.
# * `100%` of the results would yield a non-zero NPV,
# * a mean NPV of `771,416` USD,
# * a median NPV of `765,448` USD,
# * a minimum NPV of `95,968` USD, and
# * a maximum NPV of `1,584,911` USD
#
# Even though everything looks rosy from year `5` and onto `10` based on NPV, take note of the after tax cashflows from year `6` to year `10` (in the simulation shown, will differ if you rerun). We see our benefits is waning in that iteration presented and even negative in year 10. Moreover, what would happen farther out? Would it still be negative? In situations like this, it may be better to run more simulations maybe `50k` or `100k` to see more combination. If they results are still showing wanning benefit as you check some random runs this may be a point of negotiation with your vendors.
